# %% [markdown]
# With the data wrangling done, it's time to see what story the data tells. In order to do this, all of the categorical variables will be plotted.
#
# Import libraries and dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv (r"C:\Users\Laura-Black\Documents\PhD\Data Scientist\Springboard\Capstone Projects\Drug Abuse ED Visits\Output files\Capstone1DataWrangling.csv", 
                     index_col=0, dtype={"Buyer_Part_Number": str}, low_memory=False)

print(df.head())
print(df.head())
# Out:
#               METRO  STRATA  PSU  REPLICATE   CASEWGT  PSUFRAME   AGECAT  \
# CASEID
# 1          New York      25  108          2  0.942635         3    18-20
# 2          New York      29  129          2  5.992011         9     > 65
# 3       Date County       7   25          1  4.723172         6     > 65
# 4           Phoenix       8   29          2  4.080147         6  06-11\t
# 5            Boston      22   94          2  5.177709        10    25-29
#
#            SEX      RACE  YEAR  ...       DRUGID_22        ROUTE_22  \
# CASEID                          ...
# 1         Male     Black  2011  ...  Not Applicable  Not Applicable
# 2         Male  Hispanic  2011  ...  Not Applicable  Not Applicable
# 3       Female     Black  2011  ...  Not Applicable  Not Applicable
# 4         Male  Hispanic  2011  ...  Not Applicable  Not Applicable
# 5         Male  Hispanic  2011  ...  Not Applicable  Not Applicable
#
#             TOXTEST_22          CASETYPE        DISPOSITION ALCOHOL  \
# ...

# %%
print(df.info())
print(list(df.columns.values))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229211 entries, 1 to 229211
# Data columns (total 86 columns):
# METRO           229211 non-null object
# STRATA          229211 non-null int64
# PSU             229211 non-null int64
# REPLICATE       229211 non-null int64
# CASEWGT         229211 non-null float64
# PSUFRAME        229211 non-null int64
# AGECAT          229211 non-null object
# SEX             229211 non-null object
# RACE            229211 non-null object
# YEAR            229211 non-null int64
# QUARTER         229211 non-null int64
# DAYPART         229211 non-null object
# NUMSUBS         229211 non-null int64
# DRUGID_1        229211 non-null object
# ROUTE_1         229211 non-null object
# TOXTEST_1       229211 non-null object
# DRUGID_2        229211 non-null object
# ROUTE_2         229211 non-null object
# TOXTEST_2       229211 non-null object
# DRUGID_3        229211 non-null object
# ROUTE_3         229211 non-null object
# ...

# %% [markdown]
# Plot Metro distribution

# %%
plt.figure(figsize=(16,10))
sns.countplot(x='METRO',data=df,order = df['METRO'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Metro Area', fontsize=30)
plt.xlabel('Metro Area', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Gender distribution

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='SEX',data=df)
plt.xticks(rotation=45)
plt.title('Gender', fontsize=30)
plt.xlabel('Gender', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Race distribution

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='RACE',data=df,order = df['RACE'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Race', fontsize=30)
plt.xlabel('Race', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Age Category distribution

# %%
plt.figure(figsize=(16,10))
counts = df["AGECAT"].value_counts().sort_index()
colors = plt.cm.tab10(np.arange(len(counts)))
ax = counts.plot.bar(color=colors)
plt.xticks(rotation=45)
plt.title('Age Category', fontsize=30)
plt.xlabel('Age Category', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Quarter distribution

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='QUARTER',data=df)
plt.title('Quarter of Year', fontsize=30)
plt.xlabel('Quarter of Year', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Time of Day distribution

# %%
plt.figure(figsize=(12,6))
order = ["12:00-5:59 AM","6:00-11:59 AM","12:00-5:59 PM","6:00-11:59 PM"]
counts = df["DAYPART"].value_counts().sort_index().loc[order]
colors = plt.cm.tab10(np.arange(len(counts)))
ax = counts.plot.bar(color=colors)
plt.xticks(rotation=45)
plt.title('Time of Day', fontsize=30)
plt.xlabel('Time of Day', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Drug ID distribution

# %% [markdown]
# Plot distribution of the Drug(s) involved in the case. Showing top 10 since there are > 2600 drugs possible. The graph would be too large and hard to read.

# %%
plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_1", data=df, order=df.DRUGID_1.value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('1st Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_2", data=df, order=df[df.DRUGID_2 != "Not Applicable"]['DRUGID_2'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('2nd Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)


plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_3", data=df, order=df[df.DRUGID_3 != "Not Applicable"]['DRUGID_3'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('3rd Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_4", data=df, order=df[df.DRUGID_4 != "Not Applicable"]['DRUGID_4'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('4th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_5", data=df, order=df[df.DRUGID_5 != "Not Applicable"]['DRUGID_5'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('5th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_6", data=df, order=df[df.DRUGID_6 != "Not Applicable"]['DRUGID_6'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('6th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_7", data=df, order=df[df.DRUGID_7 != "Not Applicable"]['DRUGID_7'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('7th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_8", data=df, order=df[df.DRUGID_8 != "Not Applicable"]['DRUGID_8'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('8th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_9", data=df, order=df[df.DRUGID_9 != "Not Applicable"]['DRUGID_9'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('9th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_10", data=df, order=df[df.DRUGID_10 != "Not Applicable"]['DRUGID_10'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('10th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_11", data=df, order=df[df.DRUGID_11 != "Not Applicable"]['DRUGID_11'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('11th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_12", data=df, order=df[df.DRUGID_12 != "Not Applicable"]['DRUGID_12'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('12th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_13", data=df, order=df[df.DRUGID_13 != "Not Applicable"]['DRUGID_13'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('13th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_14", data=df, order=df[df.DRUGID_14 != "Not Applicable"]['DRUGID_14'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('14th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_15", data=df, order=df[df.DRUGID_15 != "Not Applicable"]['DRUGID_15'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('15th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_16", data=df, order=df[df.DRUGID_16 != "Not Applicable"]['DRUGID_16'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('16th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_17", data=df, order=df[df.DRUGID_17 != "Not Applicable"]['DRUGID_17'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('17th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_18", data=df, order=df[df.DRUGID_18 != "Not Applicable"]['DRUGID_18'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('18th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_19", data=df, order=df[df.DRUGID_19 != "Not Applicable"]['DRUGID_19'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('19th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_20", data=df, order=df[df.DRUGID_20 != "Not Applicable"]['DRUGID_20'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('20th Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_21", data=df, order=df[df.DRUGID_21 != "Not Applicable"]['DRUGID_21'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('21st Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(x="DRUGID_22", data=df, order=df[df.DRUGID_22 != "Not Applicable"]['DRUGID_22'].value_counts().iloc[:10].index)
plt.xticks(rotation=45)
plt.title('22nd Drug Noted in Case', fontsize=30)
plt.xlabel('Drug Name', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# C:\Users\Laura-Black\Anaconda3\lib\site-packages\ipykernel_launcher.py:146: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\Laura-Black\Anaconda3\lib\site-packages\ipykernel_launcher.py:153: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Route of Administration Columns

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_1'],order = df['ROUTE_1'].value_counts().index)
plt.xticks(rotation=45)
plt.title('1st Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_2'],order = df['ROUTE_2'].value_counts().index)
plt.xticks(rotation=45)
plt.title('2nd Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_3'],order = df['ROUTE_3'].value_counts().index)
plt.xticks(rotation=45)
plt.title('3rd Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_4'],order = df['ROUTE_4'].value_counts().index)
plt.xticks(rotation=45)
plt.title('4th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_5'],order = df['ROUTE_5'].value_counts().index)
plt.xticks(rotation=45)
plt.title('5th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_6'],order = df['ROUTE_6'].value_counts().index)
plt.xticks(rotation=45)
plt.title('6th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_7'],order = df['ROUTE_7'].value_counts().index)
plt.xticks(rotation=45)
plt.title('7th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_8'],order = df['ROUTE_8'].value_counts().index)
plt.xticks(rotation=45)
plt.title('8th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_9'],order = df['ROUTE_9'].value_counts().index)
plt.xticks(rotation=45)
plt.title('9th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_10'],order = df['ROUTE_10'].value_counts().index)
plt.xticks(rotation=45)
plt.title('10th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_11'],order = df['ROUTE_11'].value_counts().index)
plt.xticks(rotation=45)
plt.title('11th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_12'],order = df['ROUTE_12'].value_counts().index)
plt.xticks(rotation=45)
plt.title('12th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_13'],order = df['ROUTE_13'].value_counts().index)
plt.xticks(rotation=45)
plt.title('13th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_14'],order = df['ROUTE_14'].value_counts().index)
plt.xticks(rotation=45)
plt.title('14th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_15'],order = df['ROUTE_15'].value_counts().index)
plt.xticks(rotation=45)
plt.title('15th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_16'],order = df['ROUTE_16'].value_counts().index)
plt.xticks(rotation=45)
plt.title('16th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)


plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_17'],order = df['ROUTE_17'].value_counts().index)
plt.xticks(rotation=45)
plt.title('17th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_18'],order = df['ROUTE_18'].value_counts().index)
plt.xticks(rotation=45)
plt.title('18th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_19'],order = df['ROUTE_19'].value_counts().index)
plt.xticks(rotation=45)
plt.title('19th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_20'],order = df['ROUTE_20'].value_counts().index)
plt.xticks(rotation=45)
plt.title('20th Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_21'],order = df['ROUTE_21'].value_counts().index)
plt.xticks(rotation=45)
plt.title('21st Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['ROUTE_22'],order = df['ROUTE_22'].value_counts().index)
plt.xticks(rotation=45)
plt.title('22nd Route of Drug Ingestion Noted in Case', fontsize=25)
plt.xlabel('Route of Drug Ingestion', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# C:\Users\Laura-Black\Anaconda3\lib\site-packages\ipykernel_launcher.py:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\Laura-Black\Anaconda3\lib\site-packages\ipykernel_launcher.py:149: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of Toxicology Tests

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_1'],order = df['TOXTEST_1'].value_counts().index)
plt.xticks(rotation=45)
plt.title('1st Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_2'],order = df['TOXTEST_2'].value_counts().index)
plt.xticks(rotation=45)
plt.title('2nd Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_3'],order = df['TOXTEST_3'].value_counts().index)
plt.xticks(rotation=45)
plt.title('3rd Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_4'],order = df['TOXTEST_4'].value_counts().index)
plt.xticks(rotation=45)
plt.title('4th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_5'],order = df['TOXTEST_5'].value_counts().index)
plt.xticks(rotation=45)
plt.title('5th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_6'],order = df['TOXTEST_6'].value_counts().index)
plt.xticks(rotation=45)
plt.title('6th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_7'],order = df['TOXTEST_7'].value_counts().index)
plt.xticks(rotation=45)
plt.title('7th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_8'],order = df['TOXTEST_8'].value_counts().index)
plt.xticks(rotation=45)
plt.title('8th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_9'],order = df['TOXTEST_9'].value_counts().index)
plt.xticks(rotation=45)
plt.title('9th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_10'],order = df['TOXTEST_10'].value_counts().index)
plt.xticks(rotation=45)
plt.title('10th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_11'],order = df['TOXTEST_11'].value_counts().index)
plt.xticks(rotation=45)
plt.title('11th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_12'],order = df['TOXTEST_12'].value_counts().index)
plt.xticks(rotation=45)
plt.title('12th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_13'],order = df['TOXTEST_13'].value_counts().index)
plt.xticks(rotation=45)
plt.title('13th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_14'],order = df['TOXTEST_14'].value_counts().index)
plt.xticks(rotation=45)
plt.title('14th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_15'],order = df['TOXTEST_15'].value_counts().index)
plt.xticks(rotation=45)
plt.title('15th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_16'],order = df['TOXTEST_16'].value_counts().index)
plt.xticks(rotation=45)
plt.title('16th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_17'],order = df['TOXTEST_17'].value_counts().index)
plt.xticks(rotation=45)
plt.title('17th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_18'],order = df['TOXTEST_18'].value_counts().index)
plt.xticks(rotation=45)
plt.title('18th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_19'],order = df['TOXTEST_19'].value_counts().index)
plt.xticks(rotation=45)
plt.title('19th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_20'],order = df['TOXTEST_20'].value_counts().index)
plt.xticks(rotation=45)
plt.title('20th Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_21'],order = df['TOXTEST_21'].value_counts().index)
plt.xticks(rotation=45)
plt.title('21st Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)

plt.figure(figsize=(12,8))
sns.countplot(df['TOXTEST_22'],order = df['TOXTEST_22'].value_counts().index)
plt.xticks(rotation=45)
plt.title('22nd Drug in Case Confirmed by Toxicology Test', fontsize=25)
plt.xlabel('Toxicology Test', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# C:\Users\Laura-Black\Anaconda3\lib\site-packages\ipykernel_launcher.py:141: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\Laura-Black\Anaconda3\lib\site-packages\ipykernel_launcher.py:148: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of the Type of Case

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['CASETYPE'],order = df['CASETYPE'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Type of Case', fontsize=25)
plt.xlabel('Case Type', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of Disposition of Case

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['DISPOSITION'],order = df['DISPOSITION'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Disposition of Case', fontsize=25)
plt.xlabel('Disposition Type', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of Alcohol Involvement

# %%
plt.figure(figsize=(9,6))
sns.countplot(df['ALCOHOL'])
plt.xticks(rotation=45)
plt.title('Alcohol Involvement', fontsize=25)
plt.xlabel('Alcohol Involvement', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of Illicit Drug Involvement

# %%
plt.figure(figsize=(9,6))
sns.countplot(df['NONALCILL'])
plt.xticks(rotation=45)
plt.title('Illicit Drug Involvement', fontsize=25)
plt.xlabel('Illicit Drug Involvement', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of Pharmaceutical Drug Involvement

# %%
plt.figure(figsize=(9,6))
sns.countplot(df['PHARMA'],order = df['PHARMA'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Pharmaceutical Drug Involvement', fontsize=25)
plt.xlabel('Pharmaceutical Drug Involvement', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of Non-Medical Pharmaceutical Drug Involvement

# %%
plt.figure(figsize=(9,6))
sns.countplot(df['NONMEDPHARMA'])
plt.xticks(rotation=45)
plt.title('Non-Medical Pharmaceutical Drug Involvement', fontsize=25)
plt.xlabel('Non-Medical Pharmaceutical Drug Involvement', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# Plot Distribution of All Misuse and Abuse Qualification

# %%
plt.figure(figsize=(9,6))
sns.countplot(df['ALLABUSE'])
plt.xticks(rotation=45)
plt.title('All Misuse and Abuse Qualification', fontsize=25)
plt.xlabel('All Misuse and Abuse Qualification', fontsize=20)
plt.ylabel('Number of Cases', fontsize=20)
# Out:
# Text(0, 0.5, 'Number of Cases')

# %% [markdown]
# This data set has 85 variables. Eighty of them are categorical. These variables include demographic information on each case, such as metro area, age, sex and race. They also include the name of the drug(s) ingested, the route by which the drug(s) was ingested and whether a toxicology report was done. There are up to 22 drugs involved in a case. Also include in the data are the type of case, it’s disposition, whether alcohol was involved, and whether the drugs were illicit, pharmaceutical or non-medical pharmaceutical.
